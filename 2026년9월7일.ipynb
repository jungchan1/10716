# %% [markdown]
# <a href="https://colab.research.google.com/github/jungchan1/10716/blob/main/2026%EB%85%849%EC%9B%947%EC%9D%BC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from datetime import datetime,date,time

# %%
print('<디데이(D-day) 프로그램>')
print()
year = int(input('연도를 입력하세요:'))
month = int(input('월을 입력하세요:'))
day = int(input('일을 입력하세요:'))
dt4 = date(year,month,day)
today = date.toda()
# Out:
# <디데이(D-day) 프로그램>
